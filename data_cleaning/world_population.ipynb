# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

df = pd.read_csv("world_population_data.csv")
#get thr summary of the dataset(mean/standard diviation and all)
#df.describe()

#check na values 
#df.isna().sum()

#check for duplicates 
#df.duplicated().sum()

#visualise 2023 population
#sns.histplot(df["2023 population"], bins= 10, kde= True)
#plt.title("2023 population")
#plt.ylabel("Population")
#plt.xlabel("Frequency")

#group data by continent and calcu;ate the mean fro each continent 
#df.groupby("continent")["2023 population"].mean()

#piechat of top 10 countries 
top_10_countries = df.sort_values(by= "2023 population",ascending=False).head(10)
sns.barplot(x="2023 population", y="country", data= top_10_countries, )
plt.title("Top ten countries ")
plt.xlabel("Population")
plt.ylabel("Country")
plt.show()

# %%
sns.scatterplot(x="2023 population", y= "density (km²)", data= df)
plt.title("2023 population and desnity scatter plot")
plt.xlabel("2025 Population")
plt.ylabel("density (km²)")
# Out:
# Text(0, 0.5, 'density (km²)')

# %%
df.groupby(by="continent")["area (km²)"].sum().sort_values(ascending=False)
# Out:
# continent
# Oceania           8515218.00
# South America    17833382.00
# Europe           23010411.26
# North America    24244178.00
# Africa           30317963.00
# Asia             32138143.90
# Name: area (km²), dtype: float64

# %%
sns.violinplot(x="continent", y="area (km²)", data=df )
plt.title("population desnsity distribution across continent")
plt.xlabel("Continent")
plt.ylabel("Population desity distribution")
plt.show()

# %%
sns.boxplot(x = "continent", y = "density (km²)", data=df,showfliers = False)
plt.title("Population distribution")
plt.xlabel("Continent")
plt.ylabel("Polpulation Density")
plt.show()

# %%
#visualise 2023 population
sns.histplot(df["2023 population"], bins= 10, kde= True)
plt.title("2023 population")
plt.ylabel("Population")
plt.xlabel("Frequency")
# Out:
# Text(0.5, 0, 'Frequency')
